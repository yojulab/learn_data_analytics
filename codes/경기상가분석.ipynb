# %% [markdown]
# <a href="https://colab.research.google.com/github/SanghunOh/with_data_analytics/blob/main/codes/%EA%B2%BD%EA%B8%B0%EC%83%81%EA%B0%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Connect google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_root = '/content/drive/MyDrive/datas/'

# 작업 경로 설정
import os
os.chdir(path_root)
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1tHYgEz3lQF-LmtFPXRgMBDh4UN54qeAs/datas

# %%
import glob

filename_list = []
for file_name in glob.glob("./*.csv"):
    filename_list.append(file_name)
filename_list
# Out:
# ['./소상공인시장진흥공단_상가(상권)정보_경기_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_경남_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_광주_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_부산_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_서울_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_인천_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_전남_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_제주_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_충남_202203.csv',
#  './소상공인시장진흥공단_상가(상권)정보_강원_202203.csv']

# %% [markdown]
# ##read csv from files and concat DataFrammes

# %%
import pandas as pd

# %%
df_csv_list = list()
for file_name in filename_list:
  df_csv_list.append(pd.read_csv(file_name))

df_concat = pd.concat(df_csv_list)
# df_concat
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# show all rows
pd.options.display.max_columns = df_concat.shape[1]
df_concat.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명 상권업종소분류코드  \
# 0  20713599    눈높이러닝센타  NaN         R    학문/교육       R13     학문교육기타    R13A01
# 1  24510829    엠아이케이21  NaN         D       소매       D14  운동/경기용품소매    D14A01
# 2  20544673  큰손의정부부대찌개  NaN         Q       음식       Q01         한식    Q01A07
# 3  20547769       프리드림  NaN         D       소매       D16      화장품소매    D16A01
# 4  23323139        앞족애  NaN         Q       음식       Q01         한식    Q01A01
#
#     상권업종소분류명 표준산업분류코드        표준산업분류명  시도코드  시도명  시군구코드     시군구명       행정동코드  \
# 0      학습지보급   P85503       방문 교육 학원    41  경기도  41210      광명시  4121054000
# 1    운동/경기용품   G47631  운동 및 경기용품 소매업    41  경기도  41135  성남시 분당구  4113567000
# 2  부대찌개/섞어찌개   I56111        한식 음식점업    41  경기도  41570      김포시  4157051500
# 3     화장품판매점   G47813  화장품 및 방향제 소매업    41  경기도  41190      부천시  4119074600
# 4  한식/백반/한정식   I56111        한식 음식점업    41  경기도  41150     의정부시  4115061500
#
# ...

# %% [markdown]
# ##경기도 상가 현황

# %%
df_concat.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
stores_one_area = df_concat[df_concat['시도명'] == '경기도'].copy()
stores_one_area.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명 상권업종소분류코드  \
# 0  20713599    눈높이러닝센타  NaN         R    학문/교육       R13     학문교육기타    R13A01
# 1  24510829    엠아이케이21  NaN         D       소매       D14  운동/경기용품소매    D14A01
# 2  20544673  큰손의정부부대찌개  NaN         Q       음식       Q01         한식    Q01A07
# 3  20547769       프리드림  NaN         D       소매       D16      화장품소매    D16A01
# 4  23323139        앞족애  NaN         Q       음식       Q01         한식    Q01A01
#
#     상권업종소분류명 표준산업분류코드        표준산업분류명  시도코드  시도명  시군구코드     시군구명       행정동코드  \
# 0      학습지보급   P85503       방문 교육 학원    41  경기도  41210      광명시  4121054000
# 1    운동/경기용품   G47631  운동 및 경기용품 소매업    41  경기도  41135  성남시 분당구  4113567000
# 2  부대찌개/섞어찌개   I56111        한식 음식점업    41  경기도  41570      김포시  4157051500
# 3     화장품판매점   G47813  화장품 및 방향제 소매업    41  경기도  41190      부천시  4119074600
# 4  한식/백반/한정식   I56111        한식 음식점업    41  경기도  41150     의정부시  4115061500
#
# ...

# %%
stores_one_area_series = stores_one_area['시군구명'].value_counts()
stores_one_area_series
# Out:
# 화성시         30542
# 부천시         27672
# 남양주시        24813
# 평택시         23669
# 파주시         19093
# 성남시 분당구     18772
# 김포시         18637
# 시흥시         17769
# 의정부시        16305
# 광주시         16154
# 안산시 단원구     14239
# 이천시         13313
# 용인시 기흥구     13230
# 고양시 덕양구     13145
# 안양시 동안구     12513
# 수원시 권선구     12245
# 안산시 상록구     11655
# 용인시 처인구     11613
# 수원시 팔달구     11362
# 수원시 영통구     11142
# 고양시 일산동구    11094
# 하남시         10716
# 포천시         10390
# 양주시          9746
# 용인시 수지구      9416
# 고양시 일산서구     9075
# 안양시 만안구      9054
# 광명시          8939
# 오산시          8760
# 수원시 장안구      8733
# 성남시 중원구      8711
# 성남시 수정구      8579
# 안성시          8125
# 구리시          7909
# 군포시          6560
# 양평군          6318
# 여주시          6124
# 가평군          5075
# 동두천시         4449
# 의왕시          3639
# 연천군          2409
# 과천시          1822
# 고양시           285
# 용인시           105
# 안산시            17
# 수원시             5
# Name: 시군구명, dtype: int64

# %% [markdown]
# ###그래프 그리기 : 판다스 사용

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
plt.figure(figsize=(25,5))
plt.bar(stores_one_area_series.index, stores_one_area_series.values)
plt.xticks(rotation = 45)
plt.show()

# %%
# stores_one_area_series.plot?

# %%
fig = plt.figure(figsize=(30,10))
plt.subplot(121)
# stores_one_area_series.plot.bar()
stores_one_area_series.plot(kind='bar', color='r')
plt.subplot(122)
stores_one_area_series.plot.pie(autopct='%.1f%%', pctdistance=0.8)

fig.suptitle('경기도 상가 현황')
fig.tight_layout()
plt.show()

# %% [markdown]
# ##지역별 / 업종 대분류 상가 현황

# %%
stores_one_area_pivot = stores_one_area.pivot_table(index='상권업종대분류명', columns='시군구명', values='상호명', aggfunc='count')
stores_one_area_pivot
# Out:
# 시군구명         가평군   고양시  고양시 덕양구  고양시 일산동구  고양시 일산서구    과천시     광명시     광주시  \
# 상권업종대분류명
# 관광/여가/오락    60.0  22.0    315.0     288.0     186.0   25.0   205.0   431.0
# 부동산        146.0  22.0    697.0     539.0     428.0  103.0   481.0   850.0
# 생활서비스      462.0  62.0   2506.0    2163.0    1621.0  284.0  1634.0  2821.0
# 소매        1245.0  82.0   3966.0    3687.0    3074.0  709.0  2981.0  5764.0
# 숙박        1015.0   4.0     63.0      31.0      52.0    3.0    33.0   111.0
# 스포츠         77.0  14.0    215.0     182.0     139.0   25.0   117.0   221.0
# 음식        1931.0  59.0   4242.0    3365.0    2466.0  519.0  2474.0  4814.0
# 학문/교육      139.0  20.0   1141.0     839.0    1109.0  154.0  1014.0  1142.0
#
# 시군구명         구리시     군포시     김포시    남양주시    동두천시     부천시  성남시 분당구  성남시 수정구  \
# 상권업종대분류명
# 관광/여가/오락   166.0   178.0   394.0   435.0    78.0   902.0    433.0    243.0
# 부동산        376.0   299.0  1043.0  1277.0   168.0  1390.0   1153.0    486.0
# ...

# %% [markdown]
# ###heatmap 그리기

# %%
import seaborn as sns

# %%
plt.figure(figsize=(40,5))
sns.heatmap(stores_one_area_pivot, cmap='Blues', annot=True, fmt='.0f')
plt.show()
