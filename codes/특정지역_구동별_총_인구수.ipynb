# %% [markdown]
# <a href="https://colab.research.google.com/github/SanghunOh/with_data_analytics/blob/main/codes/%ED%8A%B9%EC%A0%95%EC%A7%80%EC%97%AD_%EA%B5%AC%EB%8F%99%EB%B3%84_%EC%B4%9D_%EC%9D%B8%EA%B5%AC%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###from https://jumin.mois.go.kr/index.jsp > 주민등록 인구 및 세대현황 -> 전체읍면동현황

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_root = '/content/drive/MyDrive/datas/'

# 작업 경로 설정
import os
os.chdir(path_root)
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1tHYgEz3lQF-LmtFPXRgMBDh4UN54qeAs/datas

# %%
import pandas as pd
read_df = pd.read_csv('./202206_202206_주민등록인구및세대현황_월간.csv', encoding='cp949')

read_df
# Out:
#                               행정구역 2022년06월_총인구수 2022년06월_세대수  \
# 0              서울특별시  (1100000000)     9,494,807    4,464,840
# 1           서울특별시 종로구 (1111000000)       143,624       73,728
# 2      서울특별시 종로구 청운효자동(1111051500)        11,803        5,210
# 3        서울특별시 종로구 사직동(1111053000)         9,310        4,674
# 4        서울특별시 종로구 삼청동(1111054000)         2,386        1,193
# ...                            ...           ...          ...
# 3860  제주특별자치도 서귀포시 서홍동(5013058000)        11,254        4,644
# 3861  제주특별자치도 서귀포시 대륜동(5013059000)        15,411        6,923
# 3862  제주특별자치도 서귀포시 대천동(5013060000)        13,802        6,460
# 3863  제주특별자치도 서귀포시 중문동(5013061000)        12,217        5,903
# 3864  제주특별자치도 서귀포시 예래동(5013062000)         3,919        2,018
#
#       2022년06월_세대당 인구 2022년06월_남자 인구수 2022년06월_여자 인구수  2022년06월_남여 비율
# 0                2.13       4,605,655       4,889,152            0.94
# 1                1.95          69,513          74,111            0.94
# 2                2.27           5,430           6,373            0.85
# 3                1.99           4,154           5,156            0.81
# 4                2.00           1,130           1,256            0.90
# ...               ...             ...             ...             ...
# 3860             2.42           5,556           5,698            0.98
# 3861             2.23           7,802           7,609            1.03
# 3862             2.14           6,980           6,822            1.02
# 3863             2.07           6,197           6,020            1.03
# 3864             1.94           1,998           1,921            1.04
#
# [3865 rows x 7 columns]

# %% [markdown]
# ##데이터 정리

# %% [markdown]
# ###컬럼명 정리

# %%
def replace_column_name(column_name, split_param='_'):
  split_list = column_name.split(split_param)
  result = split_list[len(split_list)-1]
  return result

# %%
read_df.columns = list(map(replace_column_name,list(read_df.columns)))

# %%
read_df
# Out:
#                               행정구역       총인구수        세대수  세대당 인구     남자 인구수  \
# 0              서울특별시  (1100000000)  9,494,807  4,464,840    2.13  4,605,655
# 1           서울특별시 종로구 (1111000000)    143,624     73,728    1.95     69,513
# 2      서울특별시 종로구 청운효자동(1111051500)     11,803      5,210    2.27      5,430
# 3        서울특별시 종로구 사직동(1111053000)      9,310      4,674    1.99      4,154
# 4        서울특별시 종로구 삼청동(1111054000)      2,386      1,193    2.00      1,130
# ...                            ...        ...        ...     ...        ...
# 3860  제주특별자치도 서귀포시 서홍동(5013058000)     11,254      4,644    2.42      5,556
# 3861  제주특별자치도 서귀포시 대륜동(5013059000)     15,411      6,923    2.23      7,802
# 3862  제주특별자치도 서귀포시 대천동(5013060000)     13,802      6,460    2.14      6,980
# 3863  제주특별자치도 서귀포시 중문동(5013061000)     12,217      5,903    2.07      6,197
# 3864  제주특별자치도 서귀포시 예래동(5013062000)      3,919      2,018    1.94      1,998
#
#          여자 인구수  남여 비율
# 0     4,889,152   0.94
# 1        74,111   0.94
# 2         6,373   0.85
# 3         5,156   0.81
# 4         1,256   0.90
# ...         ...    ...
# 3860      5,698   0.98
# 3861      7,609   1.03
# 3862      6,822   1.02
# 3863      6,020   1.03
# 3864      1,921   1.04
#
# [3865 rows x 7 columns]

# %%
read_df.dtypes
# Out:
# 행정구역       object
# 총인구수       object
# 세대수        object
# 세대당 인구    float64
# 남자 인구수     object
# 여자 인구수     object
# 남여 비율     float64
# dtype: object

# %%
change_dtype_columns = ['총인구수','세대수', '남자 인구수', '여자 인구수']
for column in change_dtype_columns:
  read_df[column] = read_df[column].str.replace(',','').astype('int64')
read_df
# Out:
#                               행정구역     총인구수      세대수  세대당 인구   남자 인구수  \
# 0              서울특별시  (1100000000)  9494807  4464840    2.13  4605655
# 1           서울특별시 종로구 (1111000000)   143624    73728    1.95    69513
# 2      서울특별시 종로구 청운효자동(1111051500)    11803     5210    2.27     5430
# 3        서울특별시 종로구 사직동(1111053000)     9310     4674    1.99     4154
# 4        서울특별시 종로구 삼청동(1111054000)     2386     1193    2.00     1130
# ...                            ...      ...      ...     ...      ...
# 3860  제주특별자치도 서귀포시 서홍동(5013058000)    11254     4644    2.42     5556
# 3861  제주특별자치도 서귀포시 대륜동(5013059000)    15411     6923    2.23     7802
# 3862  제주특별자치도 서귀포시 대천동(5013060000)    13802     6460    2.14     6980
# 3863  제주특별자치도 서귀포시 중문동(5013061000)    12217     5903    2.07     6197
# 3864  제주특별자치도 서귀포시 예래동(5013062000)     3919     2018    1.94     1998
#
#        여자 인구수  남여 비율
# 0     4889152   0.94
# 1       74111   0.94
# 2        6373   0.85
# 3        5156   0.81
# 4        1256   0.90
# ...       ...    ...
# 3860     5698   0.98
# 3861     7609   1.03
# 3862     6822   1.02
# 3863     6020   1.03
# 3864     1921   1.04
#
# [3865 rows x 7 columns]

# %% [markdown]
# ##특정 지역 구별 인구수 분석

# %%
# 서울
condition = read_df['행정구역'].str.find('구 (11') > 0

contents_df = read_df[condition].copy()
# contents_df
contents_df.shape
# Out:
# (25, 7)

# %%
contents_df['구'] = contents_df['행정구역'].str.split(' ').str[1]

# %%
contents_df.columns
# Out:
# Index(['행정구역', '총인구수', '세대수', '세대당 인구', '남자 인구수', '여자 인구수', '남여 비율', '구'], dtype='object')

# %% [markdown]
# ###구별 시각화

# %%
contents_df.sort_values('총인구수', ascending=False, inplace=True)
contents_df
# Out:
#                         행정구역    총인구수     세대수  세대당 인구  남자 인구수  여자 인구수  남여 비율  \
# 404   서울특별시 송파구 (1171000000)  662961  286119    2.32  319397  343564   0.93
# 256   서울특별시 강서구 (1150000000)  573045  274301    2.09  275233  297812   0.92
# 381   서울특별시 강남구 (1168000000)  531777  234885    2.26  254333  277444   0.92
# 168   서울특별시 노원구 (1135000000)  508066  218637    2.32  244387  263679   0.93
# 340   서울특별시 관악구 (1162000000)  486946  281423    1.73  244722  242224   1.01
# 188   서울특별시 은평구 (1138000000)  473674  216455    2.19  226148  247526   0.91
# 432   서울특별시 강동구 (1174000000)  461630  202861    2.28  226158  235472   0.96
# 237   서울특별시 양천구 (1147000000)  444548  181987    2.44  217704  226844   0.96
# 118   서울특별시 성북구 (1129000000)  433559  198089    2.19  208790  224769   0.93
# 362   서울특별시 서초구 (1165000000)  407672  169518    2.40  194819  212853   0.92
# 277   서울특별시 구로구 (1153000000)  394850  182172    2.17  194304  200546   0.97
# 101   서울특별시 중랑구 (1126000000)  388509  188188    2.06  191433  197076   0.97
# 324   서울특별시 동작구 (1159000000)  385898  187380    2.06  186506  199392   0.94
# 305  서울특별시 영등포구 (1156000000)  376437  188759    1.99  185460  190977   0.97
# 220   서울특별시 마포구 (1144000000)  367584  181138    2.03  172569  195015   0.88
# 70    서울특별시 광진구 (1121500000)  339893  169856    2.00  163920  175973   0.93
# 86   서울특별시 동대문구 (1123000000)  337330  169931    1.99  166348  170982   0.97
# 153   서울특별시 도봉구 (1132000000)  314791  139076    2.26  153014  161777   0.95
# 205  서울특별시 서대문구 (1141000000)  305623  145517    2.10  145663  159960   0.91
# 139   서울특별시 강북구 (1130500000)  296653  145048    2.05  144154  152499   0.95
# 52    서울특별시 성동구 (1120000000)  283821  134327    2.11  138162  145659   0.95
# 294   서울특별시 금천구 (1154500000)  231565  119627    1.94  116811  114754   1.02
# 35    서울특별시 용산구 (1117000000)  222263  111860    1.99  106743  115520   0.92
# 1     서울특별시 종로구 (1111000000)  143624   73728    1.95   69513   74111   0.94
# 19     서울특별시 중구 (1114000000)  122088   63958    1.91   59364   62724   0.95
#
#         구
# 404   송파구
# 256   강서구
# 381   강남구
# 168   노원구
# 340   관악구
# 188   은평구
# 432   강동구
# 237   양천구
# 118   성북구
# 362   서초구
# 277   구로구
# 101   중랑구
# 324   동작구
# 305  영등포구
# 220   마포구
# 70    광진구
# 86   동대문구
# 153   도봉구
# 205  서대문구
# 139   강북구
# 52    성동구
# 294   금천구
# 35    용산구
# 1     종로구
# 19     중구

# %%
import seaborn as sns
sns.barplot(data=contents_df, x='구', y='총인구수')
plt.title('구별 인구수')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##특정 지역 동별 인구수 분석

# %%
# 서울 송파구
condition = read_df['행정구역'].str.find('동(1171') > 0

area_df = read_df[condition].copy()
# area_df
area_df.shape
# Out:
# (27, 7)

# %%
area_df['동'] = area_df['행정구역'].str.split(' ').str[2].str.split('(').str[0]
area_df
# Out:
#                            행정구역   총인구수    세대수  세대당 인구  남자 인구수  여자 인구수  남여 비율  \
# 405  서울특별시 송파구 풍납1동(1171051000)  12644   5927    2.13    6219    6425   0.97
# 406  서울특별시 송파구 풍납2동(1171052000)  24573  10983    2.24   11651   12922   0.90
# 407  서울특별시 송파구 거여1동(1171053100)  12337   5641    2.19    6197    6140   1.01
# 408  서울특별시 송파구 거여2동(1171053200)  23410   9902    2.36   11483   11927   0.96
# 409  서울특별시 송파구 마천1동(1171054000)  18746   8837    2.12    9570    9176   1.04
# 410  서울특별시 송파구 마천2동(1171055000)  18332   8694    2.11    9351    8981   1.04
# 411  서울특별시 송파구 방이1동(1171056100)  15510   6229    2.49    7485    8025   0.93
# 412  서울특별시 송파구 방이2동(1171056200)  26277  15294    1.72   12134   14143   0.86
# 413   서울특별시 송파구 오륜동(1171056600)  17871   5934    3.01    8717    9154   0.95
# 414   서울특별시 송파구 오금동(1171057000)  38121  15688    2.43   18495   19626   0.94
# 415  서울특별시 송파구 송파1동(1171058000)  23782  12394    1.92   11135   12647   0.88
# 416  서울특별시 송파구 송파2동(1171059000)  19057   7250    2.63    9173    9884   0.93
# 417   서울특별시 송파구 석촌동(1171060000)  31391  16962    1.85   14947   16444   0.91
# 418   서울특별시 송파구 삼전동(1171061000)  29896  16055    1.86   13988   15908   0.88
# 419  서울특별시 송파구 가락본동(1171062000)  25938  11789    2.20   12858   13080   0.98
# 420  서울특별시 송파구 가락1동(1171063100)  27432   9894    2.77   13291   14141   0.94
# 421  서울특별시 송파구 가락2동(1171063200)  31643  12378    2.56   15487   16156   0.96
# 422  서울특별시 송파구 문정1동(1171064100)  19901   8522    2.34    9836   10065   0.98
# 423  서울특별시 송파구 문정2동(1171064200)  28739  15713    1.83   13148   15591   0.84
# 424   서울특별시 송파구 장지동(1171064600)  29193  12146    2.40   14097   15096   0.93
# 425   서울특별시 송파구 위례동(1171064700)  43884  14191    3.09   21400   22484   0.95
# 426  서울특별시 송파구 잠실본동(1171065000)  27875  15646    1.78   13332   14543   0.92
# 427  서울특별시 송파구 잠실2동(1171067000)  34892  11609    3.01   16652   18240   0.91
# 428  서울특별시 송파구 잠실3동(1171068000)  34139  11914    2.87   16245   17894   0.91
# 429  서울특별시 송파구 잠실4동(1171069000)  21231   7263    2.92   10194   11037   0.92
# 430  서울특별시 송파구 잠실6동(1171071000)  16653   5876    2.83    7894    8759   0.90
# 431  서울특별시 송파구 잠실7동(1171072000)   9494   3388    2.80    4418    5076   0.87
#
#         동
# 405  풍납1동
# 406  풍납2동
# 407  거여1동
# 408  거여2동
# 409  마천1동
# 410  마천2동
# 411  방이1동
# 412  방이2동
# 413   오륜동
# 414   오금동
# 415  송파1동
# 416  송파2동
# 417   석촌동
# 418   삼전동
# 419  가락본동
# 420  가락1동
# 421  가락2동
# 422  문정1동
# 423  문정2동
# 424   장지동
# 425   위례동
# 426  잠실본동
# 427  잠실2동
# 428  잠실3동
# 429  잠실4동
# 430  잠실6동
# 431  잠실7동

# %%
area_df.columns
# Out:
# Index(['행정구역', '총인구수', '세대수', '세대당 인구', '남자 인구수', '여자 인구수', '남여 비율', '동'], dtype='object')

# %% [markdown]
# ###동별 시각화

# %%
area_df.sort_values('총인구수', ascending=False, inplace=True)
area_df
# Out:
#                            행정구역   총인구수    세대수  세대당 인구  남자 인구수  여자 인구수  남여 비율  \
# 425   서울특별시 송파구 위례동(1171064700)  43884  14191    3.09   21400   22484   0.95
# 414   서울특별시 송파구 오금동(1171057000)  38121  15688    2.43   18495   19626   0.94
# 427  서울특별시 송파구 잠실2동(1171067000)  34892  11609    3.01   16652   18240   0.91
# 428  서울특별시 송파구 잠실3동(1171068000)  34139  11914    2.87   16245   17894   0.91
# 421  서울특별시 송파구 가락2동(1171063200)  31643  12378    2.56   15487   16156   0.96
# 417   서울특별시 송파구 석촌동(1171060000)  31391  16962    1.85   14947   16444   0.91
# 418   서울특별시 송파구 삼전동(1171061000)  29896  16055    1.86   13988   15908   0.88
# 424   서울특별시 송파구 장지동(1171064600)  29193  12146    2.40   14097   15096   0.93
# 423  서울특별시 송파구 문정2동(1171064200)  28739  15713    1.83   13148   15591   0.84
# 426  서울특별시 송파구 잠실본동(1171065000)  27875  15646    1.78   13332   14543   0.92
# 420  서울특별시 송파구 가락1동(1171063100)  27432   9894    2.77   13291   14141   0.94
# 412  서울특별시 송파구 방이2동(1171056200)  26277  15294    1.72   12134   14143   0.86
# 419  서울특별시 송파구 가락본동(1171062000)  25938  11789    2.20   12858   13080   0.98
# 406  서울특별시 송파구 풍납2동(1171052000)  24573  10983    2.24   11651   12922   0.90
# 415  서울특별시 송파구 송파1동(1171058000)  23782  12394    1.92   11135   12647   0.88
# 408  서울특별시 송파구 거여2동(1171053200)  23410   9902    2.36   11483   11927   0.96
# 429  서울특별시 송파구 잠실4동(1171069000)  21231   7263    2.92   10194   11037   0.92
# 422  서울특별시 송파구 문정1동(1171064100)  19901   8522    2.34    9836   10065   0.98
# 416  서울특별시 송파구 송파2동(1171059000)  19057   7250    2.63    9173    9884   0.93
# 409  서울특별시 송파구 마천1동(1171054000)  18746   8837    2.12    9570    9176   1.04
# 410  서울특별시 송파구 마천2동(1171055000)  18332   8694    2.11    9351    8981   1.04
# 413   서울특별시 송파구 오륜동(1171056600)  17871   5934    3.01    8717    9154   0.95
# 430  서울특별시 송파구 잠실6동(1171071000)  16653   5876    2.83    7894    8759   0.90
# 411  서울특별시 송파구 방이1동(1171056100)  15510   6229    2.49    7485    8025   0.93
# 405  서울특별시 송파구 풍납1동(1171051000)  12644   5927    2.13    6219    6425   0.97
# 407  서울특별시 송파구 거여1동(1171053100)  12337   5641    2.19    6197    6140   1.01
# 431  서울특별시 송파구 잠실7동(1171072000)   9494   3388    2.80    4418    5076   0.87
#
#         동
# 425   위례동
# 414   오금동
# 427  잠실2동
# 428  잠실3동
# 421  가락2동
# 417   석촌동
# 418   삼전동
# 424   장지동
# 423  문정2동
# 426  잠실본동
# 420  가락1동
# 412  방이2동
# 419  가락본동
# 406  풍납2동
# 415  송파1동
# 408  거여2동
# 429  잠실4동
# 422  문정1동
# 416  송파2동
# 409  마천1동
# 410  마천2동
# 413   오륜동
# 430  잠실6동
# 411  방이1동
# 405  풍납1동
# 407  거여1동
# 431  잠실7동

# %%
import seaborn as sns
sns.barplot(data=area_df, x='동', y='총인구수')
plt.title('동별 인구수')
plt.xticks(rotation=45)
plt.show()
