# %% [markdown]
# <a href="https://colab.research.google.com/github/SanghunOh/with_data_analytics/blob/main/codes/%EC%8B%9C%EB%8F%84%EB%B3%84_%EC%B4%9D_%EC%9D%B8%EA%B5%AC%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###from https://jumin.mois.go.kr/index.jsp > 주민등록 인구 및 세대현황 -> 전체읍면동현황

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_root = '/content/drive/MyDrive/datas/'

# 작업 경로 설정
import os
os.chdir(path_root)
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1tHYgEz3lQF-LmtFPXRgMBDh4UN54qeAs/datas

# %%
import pandas as pd
read_df = pd.read_csv('./202206_202206_주민등록인구및세대현황_월간.csv', encoding='cp949')

read_df
# Out:
#                               행정구역 2022년06월_총인구수 2022년06월_세대수  \
# 0              서울특별시  (1100000000)     9,494,807    4,464,840
# 1           서울특별시 종로구 (1111000000)       143,624       73,728
# 2      서울특별시 종로구 청운효자동(1111051500)        11,803        5,210
# 3        서울특별시 종로구 사직동(1111053000)         9,310        4,674
# 4        서울특별시 종로구 삼청동(1111054000)         2,386        1,193
# ...                            ...           ...          ...
# 3860  제주특별자치도 서귀포시 서홍동(5013058000)        11,254        4,644
# 3861  제주특별자치도 서귀포시 대륜동(5013059000)        15,411        6,923
# 3862  제주특별자치도 서귀포시 대천동(5013060000)        13,802        6,460
# 3863  제주특별자치도 서귀포시 중문동(5013061000)        12,217        5,903
# 3864  제주특별자치도 서귀포시 예래동(5013062000)         3,919        2,018
#
#       2022년06월_세대당 인구 2022년06월_남자 인구수 2022년06월_여자 인구수  2022년06월_남여 비율
# 0                2.13       4,605,655       4,889,152            0.94
# 1                1.95          69,513          74,111            0.94
# 2                2.27           5,430           6,373            0.85
# 3                1.99           4,154           5,156            0.81
# 4                2.00           1,130           1,256            0.90
# ...               ...             ...             ...             ...
# 3860             2.42           5,556           5,698            0.98
# 3861             2.23           7,802           7,609            1.03
# 3862             2.14           6,980           6,822            1.02
# 3863             2.07           6,197           6,020            1.03
# 3864             1.94           1,998           1,921            1.04
#
# [3865 rows x 7 columns]

# %% [markdown]
# ##데이터 정리

# %% [markdown]
# ###컬럼명 정리

# %%
def replace_column_name(column_name, split_param='_'):
  split_list = column_name.split(split_param)
  result = split_list[len(split_list)-1]
  return result

# %%
read_df.columns = list(map(replace_column_name,list(read_df.columns)))

# %%
read_df
# Out:
#                               행정구역       총인구수        세대수  세대당 인구     남자 인구수  \
# 0              서울특별시  (1100000000)  9,494,807  4,464,840    2.13  4,605,655
# 1           서울특별시 종로구 (1111000000)    143,624     73,728    1.95     69,513
# 2      서울특별시 종로구 청운효자동(1111051500)     11,803      5,210    2.27      5,430
# 3        서울특별시 종로구 사직동(1111053000)      9,310      4,674    1.99      4,154
# 4        서울특별시 종로구 삼청동(1111054000)      2,386      1,193    2.00      1,130
# ...                            ...        ...        ...     ...        ...
# 3860  제주특별자치도 서귀포시 서홍동(5013058000)     11,254      4,644    2.42      5,556
# 3861  제주특별자치도 서귀포시 대륜동(5013059000)     15,411      6,923    2.23      7,802
# 3862  제주특별자치도 서귀포시 대천동(5013060000)     13,802      6,460    2.14      6,980
# 3863  제주특별자치도 서귀포시 중문동(5013061000)     12,217      5,903    2.07      6,197
# 3864  제주특별자치도 서귀포시 예래동(5013062000)      3,919      2,018    1.94      1,998
#
#          여자 인구수  남여 비율
# 0     4,889,152   0.94
# 1        74,111   0.94
# 2         6,373   0.85
# 3         5,156   0.81
# 4         1,256   0.90
# ...         ...    ...
# 3860      5,698   0.98
# 3861      7,609   1.03
# 3862      6,822   1.02
# 3863      6,020   1.03
# 3864      1,921   1.04
#
# [3865 rows x 7 columns]

# %%
read_df.dtypes
# Out:
# 행정구역       object
# 총인구수       object
# 세대수        object
# 세대당 인구    float64
# 남자 인구수     object
# 여자 인구수     object
# 남여 비율     float64
# dtype: object

# %%
change_dtype_columns = ['총인구수','세대수', '남자 인구수', '여자 인구수']
for column in change_dtype_columns:
  read_df[column] = read_df[column].str.replace(',','').astype('int64')
read_df
# Out:
#                               행정구역     총인구수      세대수  세대당 인구   남자 인구수  \
# 0              서울특별시  (1100000000)  9494807  4464840    2.13  4605655
# 1           서울특별시 종로구 (1111000000)   143624    73728    1.95    69513
# 2      서울특별시 종로구 청운효자동(1111051500)    11803     5210    2.27     5430
# 3        서울특별시 종로구 사직동(1111053000)     9310     4674    1.99     4154
# 4        서울특별시 종로구 삼청동(1111054000)     2386     1193    2.00     1130
# ...                            ...      ...      ...     ...      ...
# 3860  제주특별자치도 서귀포시 서홍동(5013058000)    11254     4644    2.42     5556
# 3861  제주특별자치도 서귀포시 대륜동(5013059000)    15411     6923    2.23     7802
# 3862  제주특별자치도 서귀포시 대천동(5013060000)    13802     6460    2.14     6980
# 3863  제주특별자치도 서귀포시 중문동(5013061000)    12217     5903    2.07     6197
# 3864  제주특별자치도 서귀포시 예래동(5013062000)     3919     2018    1.94     1998
#
#        여자 인구수  남여 비율
# 0     4889152   0.94
# 1       74111   0.94
# 2        6373   0.85
# 3        5156   0.81
# 4        1256   0.90
# ...       ...    ...
# 3860     5698   0.98
# 3861     7609   1.03
# 3862     6822   1.02
# 3863     6020   1.03
# 3864     1921   1.04
#
# [3865 rows x 7 columns]

# %% [markdown]
# ##시도별 서브셋 만들기

# %%
administrative_df = read_df[read_df['행정구역'].str.contains('00000000')].copy()

# %%
administrative_df
# Out:
#                        행정구역      총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  \
# 0       서울특별시  (1100000000)   9494807  4464840    2.13  4605655  4889152
# 452     부산광역시  (2600000000)   3336737  1556938    2.14  1630944  1705793
# 674     대구광역시  (2700000000)   2375306  1070705    2.22  1169571  1205735
# 827     인천광역시  (2800000000)   2957066  1313975    2.25  1480432  1476634
# 1000    광주광역시  (2900000000)   1435378   650131    2.21   709685   725693
# 1103    대전광역시  (3000000000)   1448401   670279    2.16   722517   725884
# 1191    울산광역시  (3100000000)   1115609   485652    2.30   573152   542457
# 1253  세종특별자치시  (3600000000)    380215   158258    2.40   189723   190492
# 1277      경기도  (4100000000)  13585967  5898050    2.30  6838396  6747571
# 1894      강원도  (4200000000)   1539064   753336    2.04   774405   764659
# 2107     충청북도  (4300000000)   1597118   769180    2.08   811127   785991
# 2277     충청남도  (4400000000)   2120201  1012446    2.09  1084712  1035489
# 2505     전라북도  (4500000000)   1778279   853717    2.08   884908   893371
# 2767     전라남도  (4600000000)   1826440   907953    2.01   919417   907023
# 3113     경상북도  (4700000000)   2613963  1284663    2.03  1318198  1295765
# 3482     경상남도  (4800000000)   3295615  1515190    2.18  1659245  1636370
# 3819  제주특별자치도  (5000000000)    678012   310265    2.19   339697   338315
#
#       남여 비율
# 0      0.94
# 452    0.96
# 674    0.97
# 827    1.00
# 1000   0.98
# 1103   1.00
# 1191   1.06
# 1253   1.00
# 1277   1.01
# 1894   1.01
# 2107   1.03
# 2277   1.05
# 2505   0.99
# 2767   1.01
# 3113   1.02
# 3482   1.01
# 3819   1.00

# %%
administrative_df['시도'] = administrative_df['행정구역'].str.split(' ').str[0]
administrative_df
# Out:
#                        행정구역      총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  \
# 0       서울특별시  (1100000000)   9494807  4464840    2.13  4605655  4889152
# 452     부산광역시  (2600000000)   3336737  1556938    2.14  1630944  1705793
# 674     대구광역시  (2700000000)   2375306  1070705    2.22  1169571  1205735
# 827     인천광역시  (2800000000)   2957066  1313975    2.25  1480432  1476634
# 1000    광주광역시  (2900000000)   1435378   650131    2.21   709685   725693
# 1103    대전광역시  (3000000000)   1448401   670279    2.16   722517   725884
# 1191    울산광역시  (3100000000)   1115609   485652    2.30   573152   542457
# 1253  세종특별자치시  (3600000000)    380215   158258    2.40   189723   190492
# 1277      경기도  (4100000000)  13585967  5898050    2.30  6838396  6747571
# 1894      강원도  (4200000000)   1539064   753336    2.04   774405   764659
# 2107     충청북도  (4300000000)   1597118   769180    2.08   811127   785991
# 2277     충청남도  (4400000000)   2120201  1012446    2.09  1084712  1035489
# 2505     전라북도  (4500000000)   1778279   853717    2.08   884908   893371
# 2767     전라남도  (4600000000)   1826440   907953    2.01   919417   907023
# 3113     경상북도  (4700000000)   2613963  1284663    2.03  1318198  1295765
# 3482     경상남도  (4800000000)   3295615  1515190    2.18  1659245  1636370
# 3819  제주특별자치도  (5000000000)    678012   310265    2.19   339697   338315
#
#       남여 비율       시도
# 0      0.94    서울특별시
# 452    0.96    부산광역시
# 674    0.97    대구광역시
# 827    1.00    인천광역시
# 1000   0.98    광주광역시
# 1103   1.00    대전광역시
# 1191   1.06    울산광역시
# 1253   1.00  세종특별자치시
# 1277   1.01      경기도
# 1894   1.01      강원도
# 2107   1.03     충청북도
# 2277   1.05     충청남도
# 2505   0.99     전라북도
# 2767   1.01     전라남도
# 3113   1.02     경상북도
# 3482   1.01     경상남도
# 3819   1.00  제주특별자치도

# %% [markdown]
# ###총 인구수로 시각화

# %%
administrative_df.sort_values('총인구수', ascending=False, inplace=True)

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 62 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
plt.rcParams['figure.figsize']=(15,3)
plt.bar(administrative_df['시도'], administrative_df['총인구수'])
plt.xticks(rotation=45)
plt.title('시도별 총 인구수', size=20)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ###seaborn 사용

# %%
import seaborn as sns
sns.barplot(data=administrative_df, x='시도', y='총인구수')
plt.title('시도별 총 인구수', size=20)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ###파이그래프

# %%
plt.pie(administrative_df['총인구수'], labels=administrative_df['시도'],
        autopct='%.1f%%', pctdistance=0.8, rotatelabels=True)
plt.title('시도별 총 인구수', size=20)
plt.show()
